# %%
import pandas as pd
import numpy as np

# %%
# lectura de archivo y lo convierte en un DF
df_Flight = pd.read_csv(r"C:\Users\Usuario\Desktop\Ejercicios Modulo3\files/Customer Flight Activity.csv")
df_Loyalty = pd.read_csv(r"C:\Users\Usuario\Desktop\Ejercicios Modulo3\files/Customer Loyalty History.csv")

# %%
# unión mediante "Loyalty number" porque ambos contienen info de un mismo cliente(ID)
df_merge = df_Flight.merge(df_Loyalty, how = 'left', left_on = 'Loyalty Number', right_on = 'Loyalty Number')
df_merge.head()

df_final = df_merge.copy()

# %%
# resultado
df_final.columns
# Out:
# Index(['Loyalty Number', 'Year', 'Month', 'Flights Booked',
#        'Flights with Companions', 'Total Flights', 'Distance',
#        'Points Accumulated', 'Points Redeemed', 'Dollar Cost Points Redeemed',
#        'Country', 'Province', 'City', 'Postal Code', 'Gender', 'Education',
#        'Salary', 'Marital Status', 'Loyalty Card', 'CLV', 'Enrollment Type',
#        'Enrollment Year', 'Enrollment Month', 'Cancellation Year',
#        'Cancellation Month'],
#       dtype='object')

# %%
# PRIMER VISTAZO a los datos
df_final.head(10)
# Out:
#    Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0          100018  2017      1               3                        0
# 1          100102  2017      1              10                        4
# 2          100140  2017      1               6                        0
# 3          100214  2017      1               0                        0
# 4          100272  2017      1               0                        0
# 5          100301  2017      1               0                        0
# 6          100364  2017      1               0                        0
# 7          100380  2017      1               0                        0
# 8          100428  2017      1               6                        0
# 9          100504  2017      1               0                        0
#
#    Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
# 2              6      1200               120.0                0
# 3              0         0                 0.0                0
# 4              0         0                 0.0                0
# 5              0         0                 0.0                0
# 6              0         0                 0.0                0
# 7              0         0                 0.0                0
# 8              6       606                60.0                0
# 9              0         0                 0.0                0
#
#    Dollar Cost Points Redeemed  ... Education   Salary Marital Status  \
# 0                            0  ...  Bachelor  92552.0        Married
# 1                            0  ...   College      NaN         Single
# 2                            0  ...   College      NaN       Divorced
# 3                            0  ...  Bachelor  63253.0        Married
# 4                            0  ...  Bachelor  91163.0       Divorced
# 5                            0  ...  Bachelor  70323.0       Divorced
# 6                            0  ...  Bachelor  76849.0        Married
# 7                            0  ...  Bachelor  69695.0         Single
# 8                            0  ...  Bachelor  63478.0        Married
# 9                            0  ...  Bachelor  75638.0       Divorced
#
#   Loyalty Card       CLV Enrollment Type  Enrollment Year Enrollment Month  \
# 0       Aurora   7919.20        Standard             2016                8
# 1         Nova   2887.74        Standard             2013                3
# 2         Nova   2838.07        Standard             2016                7
# 3         Star   4170.57        Standard             2015                8
# 4         Star   6622.05        Standard             2014                1
# 5         Nova  48356.96        Standard             2013                9
# 6         Nova   5143.88        Standard             2015                5
# 7         Star   2465.62        Standard             2012               10
# 8       Aurora   5845.43        Standard             2012                8
# 9         Nova   8807.61        Standard             2017                7
#
#   Cancellation Year  Cancellation Month
# 0               NaN                 NaN
# 1               NaN                 NaN
# 2               NaN                 NaN
# 3               NaN                 NaN
# 4               NaN                 NaN
# 5               NaN                 NaN
# 6               NaN                 NaN
# 7               NaN                 NaN
# 8               NaN                 NaN
# 9            2018.0                 3.0
#
# [10 rows x 25 columns]

# %%
df_final.tail(10)
# Out:
#         Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 405614          999631  2018     12              11                        1
# 405615          999891  2018     10               0                        0
# 405616          999758  2018     12               1                        0
# 405617          999891  2018     11               0                        0
# 405618          999891  2018     12               0                        0
# 405619          999902  2018     12               0                        0
# 405620          999911  2018     12               0                        0
# 405621          999940  2018     12               3                        0
# 405622          999982  2018     12               0                        0
# 405623          999986  2018     12               0                        0
#
#         Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 405614             12      2244               224.0                0
# 405615              0         0                 0.0                0
# 405616              1       896                89.0                0
# 405617              0         0                 0.0                0
# 405618              0         0                 0.0                0
# 405619              0         0                 0.0                0
# 405620              0         0                 0.0                0
# 405621              3      1233               123.0                0
# 405622              0         0                 0.0                0
# 405623              0         0                 0.0                0
#
#         Dollar Cost Points Redeemed  ... Education    Salary Marital Status  \
# 405614                            0  ...  Bachelor   47349.0       Divorced
# 405615                            0  ...  Bachelor   75616.0        Married
# 405616                            0  ...   College       NaN         Single
# 405617                            0  ...  Bachelor   75616.0        Married
# 405618                            0  ...  Bachelor   75616.0        Married
# 405619                            0  ...   College       NaN        Married
# 405620                            0  ...    Doctor  217943.0         Single
# 405621                            0  ...  Bachelor   47670.0        Married
# 405622                            0  ...   College       NaN        Married
# 405623                            0  ...  Bachelor   46594.0        Married
#
#        Loyalty Card       CLV Enrollment Type  Enrollment Year  \
# 405614         Star   2572.51        Standard             2014
# 405615         Nova   3745.37        Standard             2016
# 405616         Star  18690.34        Standard             2018
# 405617         Nova   3745.37        Standard             2016
# 405618         Nova   3745.37        Standard             2016
# 405619       Aurora   7290.07        Standard             2014
# 405620         Nova   8564.77        Standard             2012
# 405621         Nova  20266.50        Standard             2017
# 405622         Star   2631.56        Standard             2018
# 405623         Nova   8257.01  2018 Promotion             2018
#
#        Enrollment Month Cancellation Year  Cancellation Month
# 405614                1               NaN                 NaN
# 405615                5            2017.0                 1.0
# 405616                8               NaN                 NaN
# 405617                5            2017.0                 1.0
# 405618                5            2017.0                 1.0
# 405619                5               NaN                 NaN
# 405620                8               NaN                 NaN
# 405621                7               NaN                 NaN
# 405622                7               NaN                 NaN
# 405623                2               NaN                 NaN
#
# [10 rows x 25 columns]

# %%
# tamaño del DF [405.624 filas, 25 columnas]

df_final.shape
# Out:
# (405624, 25)

# %%
# columnas
df_final.columns
# Out:
# Index(['Loyalty Number', 'Year', 'Month', 'Flights Booked',
#        'Flights with Companions', 'Total Flights', 'Distance',
#        'Points Accumulated', 'Points Redeemed', 'Dollar Cost Points Redeemed',
#        'Country', 'Province', 'City', 'Postal Code', 'Gender', 'Education',
#        'Salary', 'Marital Status', 'Loyalty Card', 'CLV', 'Enrollment Type',
#        'Enrollment Year', 'Enrollment Month', 'Cancellation Year',
#        'Cancellation Month'],
#       dtype='object')

# %%
# información: nº filas, columnas, nulos y tipo de datos
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405624 entries, 0 to 405623
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Loyalty Number               405624 non-null  int64
#  1   Year                         405624 non-null  int64
#  2   Month                        405624 non-null  int64
#  3   Flights Booked               405624 non-null  int64
#  4   Flights with Companions      405624 non-null  int64
#  5   Total Flights                405624 non-null  int64
#  6   Distance                     405624 non-null  int64
#  7   Points Accumulated           405624 non-null  float64
#  8   Points Redeemed              405624 non-null  int64
#  9   Dollar Cost Points Redeemed  405624 non-null  int64
#  10  Country                      405624 non-null  object
#  11  Province                     405624 non-null  object
#  12  City                         405624 non-null  object
#  13  Postal Code                  405624 non-null  object
#  14  Gender                       405624 non-null  object
#  15  Education                    405624 non-null  object
#  16  Salary                       302952 non-null  float64
#  17  Marital Status               405624 non-null  object
#  18  Loyalty Card                 405624 non-null  object
#  19  CLV                          405624 non-null  float64
#  20  Enrollment Type              405624 non-null  object
#  21  Enrollment Year              405624 non-null  int64
#  22  Enrollment Month             405624 non-null  int64
#  23  Cancellation Year            50064 non-null   float64
#  24  Cancellation Month           50064 non-null   float64
# dtypes: float64(5), int64(11), object(9)
# memory usage: 77.4+ MB

# %%
# nº nulos por columna
df_final.isna().sum()
# Out:
# Loyalty Number                      0
# Year                                0
# Month                               0
# Flights Booked                      0
# Flights with Companions             0
# Total Flights                       0
# Distance                            0
# Points Accumulated                  0
# Points Redeemed                     0
# Dollar Cost Points Redeemed         0
# Country                             0
# Province                            0
# City                                0
# Postal Code                         0
# Gender                              0
# Education                           0
# Salary                         102672
# Marital Status                      0
# Loyalty Card                        0
# CLV                                 0
# Enrollment Type                     0
# Enrollment Year                     0
# Enrollment Month                    0
# Cancellation Year              355560
# Cancellation Month             355560
# dtype: int64

# %%
# reemplazo los nulos por 0

columnas_imputadas = ["Salary", "Cancellation Year", "Cancellation Month"]

df_final[columnas_imputadas] = df_final[columnas_imputadas].fillna(0) # teemplaza NaN por 0

# %%
# confirmo que no hay nulos
df_final.isnull().any()
# Out:
# Loyalty Number                 False
# Year                           False
# Month                          False
# Flights Booked                 False
# Flights with Companions        False
# Total Flights                  False
# Distance                       False
# Points Accumulated             False
# Points Redeemed                False
# Dollar Cost Points Redeemed    False
# Country                        False
# Province                       False
# City                           False
# Postal Code                    False
# Gender                         False
# Education                      False
# Salary                         False
# Marital Status                 False
# Loyalty Card                   False
# CLV                            False
# Enrollment Type                False
# Enrollment Year                False
# Enrollment Month               False
# Cancellation Year              False
# Cancellation Month             False
# dtype: bool

# %%
# nº filas duplicadas
df_final.duplicated().sum()
# Out:
# np.int64(1864)

# %%
# El DF presenta información agregada a nivel mensual por cliente, por lo que cada cliente aparece múltiples veces en función del año y mes
df_final["Loyalty Number"].duplicated().sum()
# Out:
# np.int64(388887)

# %%
# duplicados: hay 3936 filas donde el mismo cliente aparece en el mismo año y mes

df_final.duplicated(
    subset=["Loyalty Number", "Year", "Month"]
).sum()
# Out:
# np.int64(3936)

# %%
# eliminación de duplicados: mantengo la primera fila de cada cliente/año/mes
df_final = df_final.drop_duplicates(subset=["Loyalty Number", "Year", "Month"], keep='first')

# %%
# elimino la columna 'Province'
df_final.drop(columns=['Province'], errors='ignore', inplace = True) #si no existe, no hace nada 
df_final.columns
# Out:
# Index(['Loyalty Number', 'Year', 'Month', 'Flights Booked',
#        'Flights with Companions', 'Total Flights', 'Distance',
#        'Points Accumulated', 'Points Redeemed', 'Dollar Cost Points Redeemed',
#        'Country', 'City', 'Postal Code', 'Gender', 'Education', 'Salary',
#        'Marital Status', 'Loyalty Card', 'CLV', 'Enrollment Type',
#        'Enrollment Year', 'Enrollment Month', 'Cancellation Year',
#        'Cancellation Month'],
#       dtype='object')

# %%
# uno los valores de las columnas Year y Month para añadirlos a una nueva columna: Flights Date

df_final['Flights Date'] = pd.to_datetime(df_final[['Year', 'Month']].assign(Day=1))

# elimino las columnas Year y Month

df_final = df_final.drop(columns=['Year', 'Month'])

# %%
# idem
df_final['Enrollment Date'] = pd.to_datetime(df_final[['Enrollment Year', 'Enrollment Month']].rename(columns={
'Enrollment Year': 'Year','Enrollment Month': 'Month'}).assign(Day=1))

df_final = df_final.drop(columns=['Enrollment Year', 'Enrollment Month'])

# %%
# idem: para poder poner un formato fecha debo reemplazar los 0 por NaN

df_final[['Cancellation Year', 'Cancellation Month']] = df_final[['Cancellation Year', 'Cancellation Month']].replace(0, pd.NA)

df_final['Cancellation Date'] = pd.to_datetime(             # fecha, errors = 'coerce' convierte las filas con NaN en NaT
    df_final.assign(
        year=df_final['Cancellation Year'],
        month=df_final['Cancellation Month'],
        day=1
    )[["year","month","day"]],
    errors="coerce"
)

df_final = df_final.drop(columns=['Cancellation Year', 'Cancellation Month'])

# %%
# VERIFICAR la consistencia de los datos
# métricas

df_final = df_final[df_final['Flights Booked'] >= 0]
df_final = df_final[df_final['Total Flights'] >= 0]

df_final = df_final[df_final['Distance'] >= 0]


df_final = df_final[df_final['Points Accumulated'] >= 0]
df_final = df_final[df_final['Points Redeemed'] >= 0]


df_final = df_final[df_final['Salary'] >= 0]

# fecha correcta

df_final = df_final[df_final['Flights Date'] >=  '2000-01-01']
df_final = df_final[df_final['Enrollment Date'] >=  '2000-01-01']
df_final = df_final[df_final['Cancellation Date'] >=  '2000-01-01']

# %%
# tipo de datos: cambio Points Accumulated porque tiene sentido que sea int igual que Point Redeemed
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49560 entries, 9 to 405618
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Loyalty Number               49560 non-null  int64
#  1   Flights Booked               49560 non-null  int64
#  2   Flights with Companions      49560 non-null  int64
#  3   Total Flights                49560 non-null  int64
#  4   Distance                     49560 non-null  int64
#  5   Points Accumulated           49560 non-null  float64
#  6   Points Redeemed              49560 non-null  int64
#  7   Dollar Cost Points Redeemed  49560 non-null  int64
#  8   Country                      49560 non-null  object
#  9   City                         49560 non-null  object
#  10  Postal Code                  49560 non-null  object
#  11  Gender                       49560 non-null  object
#  12  Education                    49560 non-null  object
#  13  Salary                       49560 non-null  float64
#  14  Marital Status               49560 non-null  object
#  15  Loyalty Card                 49560 non-null  object
#  16  CLV                          49560 non-null  float64
#  17  Enrollment Type              49560 non-null  object
#  18  Flights Date                 49560 non-null  datetime64[ns]
#  19  Enrollment Date              49560 non-null  datetime64[ns]
#  20  Cancellation Date            49560 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), float64(3), int64(7), object(8)
# memory usage: 8.3+ MB

# %%
# cambio Points Accumulated porque tiene sentido que sea int (igual que Point Redeemed)
df_final['Points Accumulated'] = df_final['Points Accumulated'].astype('int64')
